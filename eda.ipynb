# %% [markdown]
# #  EDA (Exploratory Data Analysis) 📊

# %% [markdown]
# ## 0. Import and Settings

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## 1. Load Data with correct headers

# %% [markdown]
# Before beginning any EDA, an essential aspect is correctly reading and loading the data. In both CSV files, the headers are missing, so we opened *census_income_metadata.txt* to extract and reconstruct the column names.

# %%
with open ('census_income_metadata.txt') as f:
    lines = f.readlines()

col_names = []
# starting from line 142 is where the columns names can be extracted
column_names_lines =lines[142:]
for l in column_names_lines:
    # this prevents from adding the columns instance weight twice
    if l.startswith('|'):
        continue
    # chnages "class of worker" => "class_of_worker"
    final_col_name = l.split(":", 1)[0].strip().replace(" ", "_")
    col_names.append(final_col_name)

# the columns income was missing
col_names.append('income')

# sanity check
len(col_names)
# Out:
# 42

# %% [markdown]
# We observe that both the training and test files contain the same number of columns, reflecting the original ~66/33% split described in the metadata. However, since this predefined split is arbitrary and not based on time, leakage risks, or any domain constraints, it is not necessary to preserve it for analysis. For EDA purposes, we therefore merge both datasets and explore the full data as a whole. Later, for modeling, we will replace the original split with a more robust and commonly used 70/10/20 train/validation/test partition. This new split will be stratified to preserve the strong class imbalance present in the original data (approximately 93% earning <50k and 7% earning >50k), ensuring consistent class proportions across all subsets and enabling stable model evaluation.

# %%
train_df = pd.read_csv('/Users/vadimmalz/Downloads/Census Income Data.csv',header=None, names= col_names, index_col=False)
print(f"Train set shape : {train_df.shape}")
test_df = pd.read_csv('/Users/vadimmalz/Downloads/Census Income Test.csv',header=None, names=col_names,index_col=False)
print(f"Test set shape : {test_df.shape}")

print(train_df['income'].value_counts()/len(train_df)*100)
print(test_df['income'].value_counts()/len(test_df)*100)
# Out:
# Train set shape : (199523, 42)
# Test set shape : (99762, 42)
# income
# - 50000.    93.794199
# 50000+.      6.205801
# Name: count, dtype: float64
# income
# - 50000.    93.799242
# 50000+.      6.200758
# Name: count, dtype: float64

# %%
df_full = pd.concat([train_df, test_df], ignore_index=True)
df_full
# Out:
#         age                  class_of_worker  detailed_industry_recode  \
# 0        73                  Not in universe                         0
# 1        58   Self-employed-not incorporated                         4
# 2        18                  Not in universe                         0
# 3         9                  Not in universe                         0
# 4        10                  Not in universe                         0
# ...     ...                              ...                       ...
# 299280   14                  Not in universe                         0
# 299281   61                          Private                         8
# 299282   24   Self-employed-not incorporated                         1
# 299283   30                          Private                        45
# 299284   67                  Not in universe                         0
#
#         detailed_occupation_recode                    education  \
# 0                                0         High school graduate
# 1                               34   Some college but no degree
# 2                                0                   10th grade
# 3                                0                     Children
# 4                                0                     Children
# ...                            ...                          ...
# 299280                           0                     Children
# 299281                          36                   11th grade
# 299282                          43            7th and 8th grade
# 299283                           2   Bachelors degree(BA AB BS)
# 299284                           0                    9th grade
#
#         wage_per_hour enroll_in_edu_inst_last_wk  \
# 0                   0            Not in universe
# 1                   0            Not in universe
# 2                   0                High school
# 3                   0            Not in universe
# 4                   0            Not in universe
# ...               ...                        ...
# 299280              0            Not in universe
# 299281              0            Not in universe
# 299282              0            Not in universe
# 299283              0            Not in universe
# 299284              0            Not in universe
#
#                             marital_stat           major_industry_code  \
# 0                                Widowed   Not in universe or children
# 1                               Divorced                  Construction
# 2                          Never married   Not in universe or children
# 3                          Never married   Not in universe or children
# 4                          Never married   Not in universe or children
# ...                                  ...                           ...
# 299280                     Never married   Not in universe or children
# 299281                         Separated   Manufacturing-durable goods
# 299282   Married-civilian spouse present                   Agriculture
# 299283   Married-civilian spouse present   Other professional services
# 299284   Married-civilian spouse present   Not in universe or children
#
#                          major_occupation_code                        race  \
# 0                              Not in universe                       White
# 1          Precision production craft & repair                       White
# 2                              Not in universe   Asian or Pacific Islander
# 3                              Not in universe                       White
# 4                              Not in universe                       White
# ...                                        ...                         ...
# 299280                         Not in universe                       White
# 299281   Machine operators assmblrs & inspctrs                       Black
# 299282            Farming forestry and fishing                       White
# 299283          Executive admin and managerial                       White
# 299284                         Not in universe                       White
#
#             hispanic_origin      sex member_of_a_labor_union  \
# 0                 All other   Female         Not in universe
# 1                 All other     Male         Not in universe
# 2                 All other   Female         Not in universe
# 3                 All other   Female         Not in universe
# 4                 All other   Female         Not in universe
# ...                     ...      ...                     ...
# 299280            All other   Female         Not in universe
# 299281            All other     Male                      No
# 299282   Mexican (Mexicano)     Male         Not in universe
# 299283            All other   Female         Not in universe
# 299284            All other     Male         Not in universe
#
#        reason_for_unemployment full_or_part_time_employment_stat  \
# 0              Not in universe                Not in labor force
# 1              Not in universe          Children or Armed Forces
# 2              Not in universe                Not in labor force
# 3              Not in universe          Children or Armed Forces
# 4              Not in universe          Children or Armed Forces
# ...                        ...                               ...
# 299280         Not in universe          Children or Armed Forces
# 299281         Not in universe               Full-time schedules
# 299282         Not in universe          Children or Armed Forces
# 299283         Not in universe               Full-time schedules
# 299284         Not in universe          Children or Armed Forces
#
#         capital_gains  capital_losses  dividends_from_stocks  \
# 0                   0               0                      0
# 1                   0               0                      0
# 2                   0               0                      0
# 3                   0               0                      0
# 4                   0               0                      0
# ...               ...             ...                    ...
# 299280              0               0                      0
# 299281              0               0                      0
# 299282              0               0                      0
# 299283              0               0                      0
# 299284              0               0                      0
#
#               tax_filer_stat region_of_previous_residence  \
# 0                   Nonfiler              Not in universe
# 1          Head of household                        South
# 2                   Nonfiler              Not in universe
# 3                   Nonfiler              Not in universe
# 4                   Nonfiler              Not in universe
# ...                      ...                          ...
# 299280              Nonfiler              Not in universe
# 299281                Single              Not in universe
# 299282   Joint both under 65              Not in universe
# 299283   Joint both under 65              Not in universe
# 299284        Joint both 65+              Not in universe
#
#        state_of_previous_residence         detailed_household_and_family_stat  \
# 0                  Not in universe   Other Rel 18+ ever marr not in subfamily
# 1                         Arkansas                                Householder
# 2                  Not in universe    Child 18+ never marr Not in a subfamily
# 3                  Not in universe      Child <18 never marr not in subfamily
# 4                  Not in universe      Child <18 never marr not in subfamily
# ...                            ...                                        ...
# 299280             Not in universe      Child <18 never marr not in subfamily
# 299281             Not in universe                      Nonfamily householder
# 299282             Not in universe        Spouse of RP of unrelated subfamily
# 299283             Not in universe                      Spouse of householder
# 299284             Not in universe                                Householder
#
#        detailed_household_summary_in_household  instance_weight  \
# 0                Other relative of householder          1700.09
# 1                                  Householder          1053.55
# 2                            Child 18 or older           991.95
# 3                 Child under 18 never married          1758.14
# 4                 Child under 18 never married          1069.16
# ...                                        ...              ...
# 299280            Child under 18 never married          1708.85
# 299281                             Householder          2511.11
# 299282              Nonrelative of householder          2083.76
# 299283                   Spouse of householder          1680.06
# 299284                             Householder          1582.48
#
#        migration_code-change_in_msa migration_code-change_in_reg  \
# 0                                 ?                            ?
# 1                        MSA to MSA                  Same county
# 2                                 ?                            ?
# 3                          Nonmover                     Nonmover
# 4                          Nonmover                     Nonmover
# ...                             ...                          ...
# 299280                            ?                            ?
# 299281                            ?                            ?
# 299282                     Nonmover                     Nonmover
# 299283                            ?                            ?
# 299284                     Nonmover                     Nonmover
#
#        migration_code-move_within_reg      live_in_this_house_1_year_ago  \
# 0                                   ?   Not in universe under 1 year old
# 1                         Same county                                 No
# 2                                   ?   Not in universe under 1 year old
# 3                            Nonmover                                Yes
# 4                            Nonmover                                Yes
# ...                               ...                                ...
# 299280                              ?   Not in universe under 1 year old
# 299281                              ?   Not in universe under 1 year old
# 299282                       Nonmover                                Yes
# 299283                              ?   Not in universe under 1 year old
# 299284                       Nonmover                                Yes
#
#        migration_prev_res_in_sunbelt  num_persons_worked_for_employer  \
# 0                                  ?                                0
# 1                                Yes                                1
# 2                                  ?                                0
# 3                    Not in universe                                0
# 4                    Not in universe                                0
# ...                              ...                              ...
# 299280                             ?                                0
# 299281                             ?                                4
# 299282               Not in universe                                2
# 299283                             ?                                5
# 299284               Not in universe                                0
#
#        family_members_under_18 country_of_birth_father  \
# 0              Not in universe           United-States
# 1              Not in universe           United-States
# 2              Not in universe                 Vietnam
# 3         Both parents present           United-States
# 4         Both parents present           United-States
# ...                        ...                     ...
# 299280    Both parents present           United-States
# 299281         Not in universe           United-States
# 299282         Not in universe                  Mexico
# 299283         Not in universe           United-States
# 299284         Not in universe           United-States
#
#        country_of_birth_mother country_of_birth_self  \
# 0                United-States         United-States
# 1                United-States         United-States
# 2                      Vietnam               Vietnam
# 3                United-States         United-States
# 4                United-States         United-States
# ...                        ...                   ...
# 299280           United-States         United-States
# 299281           United-States         United-States
# 299282                  Mexico                Mexico
# 299283           United-States         United-States
# 299284           United-States         United-States
#
#                                          citizenship  \
# 0                  Native- Born in the United States
# 1                  Native- Born in the United States
# 2                Foreign born- Not a citizen of U S
# 3                  Native- Born in the United States
# 4                  Native- Born in the United States
# ...                                              ...
# 299280             Native- Born in the United States
# 299281             Native- Born in the United States
# 299282   Foreign born- U S citizen by naturalization
# 299283             Native- Born in the United States
# 299284             Native- Born in the United States
#
#         own_business_or_self_employed  \
# 0                                   0
# 1                                   0
# 2                                   0
# 3                                   0
# 4                                   0
# ...                               ...
# 299280                              0
# 299281                              0
# 299282                              0
# 299283                              0
# 299284                              0
#
#        fill_inc_questionnaire_for_veteran's_admin  veterans_benefits  \
# 0                                 Not in universe                  2
# 1                                 Not in universe                  2
# 2                                 Not in universe                  2
# 3                                 Not in universe                  0
# 4                                 Not in universe                  0
# ...                                           ...                ...
# 299280                            Not in universe                  0
# 299281                            Not in universe                  2
# 299282                            Not in universe                  2
# 299283                            Not in universe                  2
# 299284                            Not in universe                  2
#
#         weeks_worked_in_year  year     income
# 0                          0    95   - 50000.
# 1                         52    94   - 50000.
# 2                          0    95   - 50000.
# 3                          0    94   - 50000.
# 4                          0    94   - 50000.
# ...                      ...   ...        ...
# 299280                     0    95   - 50000.
# 299281                    52    95   - 50000.
# 299282                    52    94   - 50000.
# 299283                    52    95   - 50000.
# 299284                     0    94   - 50000.
#
# [299285 rows x 42 columns]

# %% [markdown]
# ## 2. Initail Sanity Check

# %% [markdown]
# The .info() function helps clarify the types of each column so we can apply appropriate feature adjustments. Some variables are currently stored as numerical values but should in fact be treated as categorical codes. For example, detailed_occupation_recode and detailed_industry_recode appear as numeric columns, but their numeric values do not represent an order or magnitude—code “24” is not “greater” or more meaningful than code “7.” They simply map to distinct occupation/industry categories.
#
# In contrast, truly numerical features—such as age, wage_per_hour, or weeks_worked_in_year—do carry meaningful ordering, where higher values correspond to greater magnitude and may influence the likelihood of earning more or less than $50K.
#
# To proceed, we first inspect all non-string features and assign them the correct data type. Columns where the numeric ranking has semantic meaning remain numerical, while fields where numbers are just identifiers (e.g., industry or occupation codes) are cast to categorical. This ensures both proper EDA and more accurate modeling later on.

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299285 entries, 0 to 299284
# Data columns (total 42 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   age                                         299285 non-null  int64
#  1   class_of_worker                             299285 non-null  object
#  2   detailed_industry_recode                    299285 non-null  int64
#  3   detailed_occupation_recode                  299285 non-null  int64
#  4   education                                   299285 non-null  object
#  5   wage_per_hour                               299285 non-null  int64
#  6   enroll_in_edu_inst_last_wk                  299285 non-null  object
#  7   marital_stat                                299285 non-null  object
#  8   major_industry_code                         299285 non-null  object
#  9   major_occupation_code                       299285 non-null  object
#  10  race                                        299285 non-null  object
#  11  hispanic_origin                             299285 non-null  object
#  12  sex                                         299285 non-null  object
#  13  member_of_a_labor_union                     299285 non-null  object
#  14  reason_for_unemployment                     299285 non-null  object
#  15  full_or_part_time_employment_stat           299285 non-null  object
#  16  capital_gains                               299285 non-null  int64
#  17  capital_losses                              299285 non-null  int64
#  18  dividends_from_stocks                       299285 non-null  int64
#  19  tax_filer_stat                              299285 non-null  object
#  20  region_of_previous_residence                299285 non-null  object
#  21  state_of_previous_residence                 299285 non-null  object
#  22  detailed_household_and_family_stat          299285 non-null  object
#  23  detailed_household_summary_in_household     299285 non-null  object
#  24  instance_weight                             299285 non-null  float64
#  25  migration_code-change_in_msa                299285 non-null  object
#  26  migration_code-change_in_reg                299285 non-null  object
#  27  migration_code-move_within_reg              299285 non-null  object
#  28  live_in_this_house_1_year_ago               299285 non-null  object
#  29  migration_prev_res_in_sunbelt               299285 non-null  object
#  30  num_persons_worked_for_employer             299285 non-null  int64
#  31  family_members_under_18                     299285 non-null  object
#  32  country_of_birth_father                     299285 non-null  object
#  33  country_of_birth_mother                     299285 non-null  object
#  34  country_of_birth_self                       299285 non-null  object
#  35  citizenship                                 299285 non-null  object
#  36  own_business_or_self_employed               299285 non-null  int64
#  37  fill_inc_questionnaire_for_veteran's_admin  299285 non-null  object
#  38  veterans_benefits                           299285 non-null  int64
#  39  weeks_worked_in_year                        299285 non-null  int64
#  40  year                                        299285 non-null  int64
#  41  income                                      299285 non-null  object
# dtypes: float64(1), int64(12), object(29)
# memory usage: 95.9+ MB

# %%
df_full['year'].value_counts()
# Out:
# year
# 94    149643
# 95    149642
# Name: count, dtype: int64

# %%
# list of within the numerical columns that will keep as a continous and numeurcal feature

keep_numeric_cols = [
    "age",
    "wage_per_hour",
    "capital_gains",
    "capital_losses",
    "dividends_from_stocks",
    "num_persons_worked_for_employer",
    "weeks_worked_in_year",
]

# These two columns are dropped because:
# - 'year' has only two values and does not provide predictive signal for the target ('income').
# - 'instance_weight' represents the number of people in a sampling unit; it is relevant for survey
#   weighting but does not help the predictive model and would introduce noise. 
drop_cols = ["instance_weight", "year"]
target_col = ['income']

# All other columns are therefore categoricals
categorical_cols = [ col for col in df_full.columns 
                    if col not in keep_numeric_cols + drop_cols + target_col]

df_full[categorical_cols] = df_full[categorical_cols].astype(str)

# to compare with above
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299285 entries, 0 to 299284
# Data columns (total 42 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   age                                         299285 non-null  int64
#  1   class_of_worker                             299285 non-null  object
#  2   detailed_industry_recode                    299285 non-null  object
#  3   detailed_occupation_recode                  299285 non-null  object
#  4   education                                   299285 non-null  object
#  5   wage_per_hour                               299285 non-null  int64
#  6   enroll_in_edu_inst_last_wk                  299285 non-null  object
#  7   marital_stat                                299285 non-null  object
#  8   major_industry_code                         299285 non-null  object
#  9   major_occupation_code                       299285 non-null  object
#  10  race                                        299285 non-null  object
#  11  hispanic_origin                             299285 non-null  object
#  12  sex                                         299285 non-null  object
#  13  member_of_a_labor_union                     299285 non-null  object
#  14  reason_for_unemployment                     299285 non-null  object
#  15  full_or_part_time_employment_stat           299285 non-null  object
#  16  capital_gains                               299285 non-null  int64
#  17  capital_losses                              299285 non-null  int64
#  18  dividends_from_stocks                       299285 non-null  int64
#  19  tax_filer_stat                              299285 non-null  object
#  20  region_of_previous_residence                299285 non-null  object
#  21  state_of_previous_residence                 299285 non-null  object
#  22  detailed_household_and_family_stat          299285 non-null  object
#  23  detailed_household_summary_in_household     299285 non-null  object
#  24  instance_weight                             299285 non-null  float64
#  25  migration_code-change_in_msa                299285 non-null  object
#  26  migration_code-change_in_reg                299285 non-null  object
#  27  migration_code-move_within_reg              299285 non-null  object
#  28  live_in_this_house_1_year_ago               299285 non-null  object
#  29  migration_prev_res_in_sunbelt               299285 non-null  object
#  30  num_persons_worked_for_employer             299285 non-null  int64
#  31  family_members_under_18                     299285 non-null  object
#  32  country_of_birth_father                     299285 non-null  object
#  33  country_of_birth_mother                     299285 non-null  object
#  34  country_of_birth_self                       299285 non-null  object
#  35  citizenship                                 299285 non-null  object
#  36  own_business_or_self_employed               299285 non-null  object
#  37  fill_inc_questionnaire_for_veteran's_admin  299285 non-null  object
#  38  veterans_benefits                           299285 non-null  object
#  39  weeks_worked_in_year                        299285 non-null  int64
#  40  year                                        299285 non-null  int64
#  41  income                                      299285 non-null  object
# dtypes: float64(1), int64(8), object(33)
# memory usage: 95.9+ MB

# %%
# Throhgout the entire dataset there is not one single NaN however this does not mean that all information 
# is valuable and some NaNs can be present in our datset but through a different form, for instance as a string with "nan", "?" or "not in universe"
# The fact that there is no NaN value is always a good sign, but i can hide other information, delve on in later on.
df_full.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Initially, I assumed duplicates might represent different people with identical characteristics, so I considered keeping them. But the dataset includes an instance_weight column, which already indicates how many people each row represents. This means each row is intended to be unique. If we keep duplicated rows, we would artificially repeat the same weighted observation and distort the data.
#
# Since we are not using population weighting in this predictive modeling task, the instance_weight column is not needed and can be removed. Once weights are removed, duplicates provide no extra information. They simply repeat the same row and should be dropped.
#
# All duplicates belong to the majority class (<50K). Keeping them would only increase an already large class imbalance. Removing them avoids unnecessary bias while still keeping the natural ~93/7 class distribution.

# %%
df_full[df_full.duplicated()]['income'].value_counts()
# Out:
# income
# - 50000.    6735
# Name: count, dtype: int64

# %%
# percentage of duplicated 
print(f"Perceangt of duplicated within the df: {df_full.duplicated().sum() / len(df_full) * 100}")
df_full.drop_duplicates(inplace=True)
# making sure that after dropping duplciates the proportion/disctrubtion of class remains similar 
print(df_full['income'].value_counts()/len(df_full)*100)
# Out:
# Perceangt of duplicated within the df: 2.2503633660223534
# income
# - 50000.    93.653051
# 50000+.      6.346949
# Name: count, dtype: float64

# %% [markdown]
# ## 3. Numerical cols Sanity Check

# %% [markdown]
# The df.describe() function gives basic numerical summaries (mean, min, max, quartiles). This helps verify whether values fall within a reasonable range. For example:
# 	•	age ranges from 0 to 90
# 	•	weeks_worked_in_year ranges from 0 to 52
#
# These ranges make sense for the dataset.
#
# However, it is also important to look at the distribution of these numerical features, whether they are normal, skewed, or heavily concentrated in certain areas. Understanding the distribution will be useful later during feature engineering, especially when selecting the right scaling method (e.g., MinMaxScaler or StandardScaler) or deciding whether a log transformation is needed. More details on this will be covered in the feature-engineering notebook.
#
# As mentioned earlier, this notebook focuses only on EDA. Here we describe and visualize the data but do not apply any transformations or make modeling decisions yet. The goal is simply to understand the dataset so that we can make informed choices later.

# %%
df_full[keep_numeric_cols].describe()
# Out:
#                  age  wage_per_hour  capital_gains  capital_losses  \
# count  292550.000000  292550.000000  292550.000000   292550.000000
# mean       35.148737      56.369147     441.681617       37.697337
# std        22.174974     276.334763    4723.762662      272.819017
# min         0.000000       0.000000       0.000000        0.000000
# 25%        17.000000       0.000000       0.000000        0.000000
# 50%        34.000000       0.000000       0.000000        0.000000
# 75%        50.000000       0.000000       0.000000        0.000000
# max        90.000000    9999.000000   99999.000000     4608.000000
#
#        dividends_from_stocks  num_persons_worked_for_employer  \
# count          292550.000000                    292550.000000
# mean              200.322198                         2.000848
# std              1959.711763                         2.372970
# min                 0.000000                         0.000000
# 25%                 0.000000                         0.000000
# 50%                 0.000000                         1.000000
# 75%                 0.000000                         4.000000
# max             99999.000000                         6.000000
#
#        weeks_worked_in_year
# count         292550.000000
# mean              23.708146
# std               24.425794
# min                0.000000
# 25%                0.000000
# 50%               12.000000
# 75%               52.000000
# max               52.000000

# %%
# This function was done with the help of ChatGPT as i struggled with the subplots
sns.set(style="whitegrid")
def plot_numeric_distributions(df, numeric_cols):
    n = len(numeric_cols) 
    cols = 3
    rows = (n + cols - 1) // cols 
    
    plt.figure(figsize=(cols * 6, rows * 4))
    
    for i, col in enumerate(numeric_cols, 1):
        plt.subplot(rows, cols, i)
        
        sns.histplot(
            df[col],
            bins=40,
            kde=True,
            edgecolor=None
        )
        
        plt.title(f"Distribution of {col}", fontsize=12)
        plt.xlabel(col)
        plt.ylabel("Count")
    
    plt.tight_layout()
    plt.show()

plot_numeric_distributions(df_full, keep_numeric_cols)

# %%
# in depth look at one particular numerical col for exampple
df_full['age'].hist()
# Out:
# <Axes: >

# %% [markdown]
# To better understand how the numerical features relate to each other, we examine their Pearson correlation matrix. Pearson correlation values range from -1 to 1, where values close to 1 or -1 indicate strong linear or inverse linear relationships. Strong correlations may suggest that two features carry redundant information.
#
# As a general rule of thumb, correlations above 0.8 or below –0.8 can be considered high enough that one of the variables might be removed or deprioritized. In this dataset, however, most numerical features show relatively low correlations (except the work-related cols), so we do not observe any pairs that are strongly linear.
#
# Later, once the categorical variables are encoded, we will be able to compute correlations across all features, not only the numeric ones.

# %%
corr = df_full[keep_numeric_cols].corr()
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##  4. Categorical Columns

# %% [markdown]
# We now look more closely at the categorical columns. The goal is to understand their class distributions, the number of unique categories, and any imbalance within them. This information will help us choose the appropriate encoding method and may also highlight columns that can be dropped if they provide little useful information.

# %%
# First of all, for cleanliness and reproducibility, i remove all the white space 
#  ex : " not in universe " =>  "not in universe"
df_full[categorical_cols] = df_full[categorical_cols].applymap(
    lambda x: x.strip() if isinstance(x, str) else x
)
# Out:
# /var/folders/8t/vbvw23nj5_111hy85bf96bxh0000gn/T/ipykernel_86081/1998648224.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_full[categorical_cols] = df_full[categorical_cols].applymap(

# %% [markdown]
# We also observed that some categorical columns contain the value "?". This value is not informative because we do not know what it represents—it could be a missing value, an unknown category, or an error. In contrast, other ambiguous-looking categories such as "Not in universe" do have a clear meaning. For example, in the reason_for_unemployment column, "Not in universe" indicates people who are not part of the unemployment population (e.g., employed workers, students). So while "Not in universe" is a valid and useful category, "?" is not.
#
# For this reason, columns with a high percentage of "?" values may need to be removed or handled differently, depending on how frequent the "?" entries are and whether the feature still provides useful information.

# %%
# percentage of categorical coumns with "?" present
(df_full[categorical_cols] == "?").sum() /len(df_full)*100
# Out:
# class_of_worker                                0.000000
# detailed_industry_recode                       0.000000
# detailed_occupation_recode                     0.000000
# education                                      0.000000
# enroll_in_edu_inst_last_wk                     0.000000
# marital_stat                                   0.000000
# major_industry_code                            0.000000
# major_occupation_code                          0.000000
# race                                           0.000000
# hispanic_origin                                0.000000
# sex                                            0.000000
# member_of_a_labor_union                        0.000000
# reason_for_unemployment                        0.000000
# full_or_part_time_employment_stat              0.000000
# tax_filer_stat                                 0.000000
# region_of_previous_residence                   0.000000
# state_of_previous_residence                    0.353444
# detailed_household_and_family_stat             0.000000
# detailed_household_summary_in_household        0.000000
# migration_code-change_in_msa                  49.954196
# migration_code-change_in_reg                  49.954196
# migration_code-move_within_reg                49.954196
# live_in_this_house_1_year_ago                  0.000000
# migration_prev_res_in_sunbelt                 49.954196
# family_members_under_18                        0.000000
# country_of_birth_father                        3.459238
# country_of_birth_mother                        3.134165
# country_of_birth_self                          1.760383
# citizenship                                    0.000000
# own_business_or_self_employed                  0.000000
# fill_inc_questionnaire_for_veteran's_admin     0.000000
# veterans_benefits                              0.000000
# dtype: float64

# %% [markdown]
# ### ⚠️ Important code block
#
# The code block below is useful because it provides four key pieces of information for each categorical feature:
# - **The number of unique categories** -> helps for the right choice of encoding
#
# - **Top 10 most frequent categories**-> help indentify if high number of "?" for instance
#
# - **Target distribution per category**,  -> important for feature selection. For example, the data shows that individuals with a PhD or those working in architecture and engineering have around a 50% chance of earning more than $50K. This kind of information confirms that such features are relevant and should be kept. It also highlights meaningful disparities, such as differences in income by sex (see screenshot).
#
# - **Presence of suspicious or unexpected values** -> helps detect categories that may need cleaning or removal.
#
# ![Screenshot 2025-11-17 at 12.04.36.png](<attachment:Screenshot 2025-11-17 at 12.04.36.png>)

# %%
# Formatted with the help of ChatGPT
for col in categorical_cols:
    print("="*80)
    print(f"COLUMN: {col}")
    print(f"Unique categories: {df_full[col].nunique()}")
    print()
    
    print("Top 10 categories:")
    print(df_full[col].value_counts(normalize=True).head(10))
    print()
    
    print("Target distribution (% earning >50K) per category:")
    print(
        pd.crosstab(
            df_full[col],
            df_full["income"],
            normalize="index"
        ) * 100
    )
    print()
    
    weird = df_full[col].unique()
    weird = [w for w in weird if w.strip() in ["?", ""," ","Unknown"]]
    if weird:
        print(f"⚠️ Found suspicious categories: {weird}")
    else:
        print("No suspicious categories found.")

    print("="*80)
    print("\n")
# Out:
# ================================================================================
# COLUMN: class_of_worker
# Unique categories: 9
#
# Top 10 categories:
# class_of_worker
# Not in universe                   0.490921
# Private                           0.369431
# Self-employed-not incorporated    0.043487
# Local government                  0.039703
# State government                  0.021853
# Self-employed-incorporated        0.016790
# Federal government                0.014801
# Never worked                      0.002194
# Without pay                       0.000820
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                           - 50000.    50000+.
# class_of_worker
# Federal government              79.884527  20.115473
# Local government                88.936720  11.063280
# Never worked                    99.688474   0.311526
# Not in universe                 99.060709   0.939291
# Private                         89.814669  10.185331
# Self-employed-incorporated      65.736971  34.263029
# Self-employed-not incorporated  87.266153  12.733847
# State government                88.299703  11.700297
# Without pay                     99.166667   0.833333
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: detailed_industry_recode
# Unique categories: 52
#
# Top 10 categories:
# detailed_industry_recode
# 0     0.493116
# 33    0.088105
# 43    0.042752
# 4     0.030935
# 42    0.023883
# 45    0.022854
# 29    0.021942
# 37    0.021060
# 41    0.019877
# 32    0.018513
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                      - 50000.    50000+.
# detailed_industry_recode
# 0                          99.063503   0.936497
# 1                          94.117647   5.882353
# 10                        100.000000   0.000000
# 11                         81.402325  18.597675
# 12                         79.556650  20.443350
# 13                         75.768668  24.231332
# 14                         77.803204  22.196796
# 15                         76.557864  23.442136
# 16                         78.409091  21.590909
# 17                         92.035398   7.964602
# 18                         91.594203   8.405797
# 19                         92.787996   7.212004
# 2                          94.128440   5.871560
# 20                         61.538462  38.461538
# 21                         94.517282   5.482718
# 22                         95.988740   4.011260
# 23                         82.603254  17.396746
# 24                         88.087774  11.912226
# 25                         72.495214  27.504786
# 26                         61.748634  38.251366
# 27                         89.576547  10.423453
# 28                         93.689320   6.310680
# 29                         88.471725  11.528275
# 3                          74.324324  25.675676
# 30                         76.632883  23.367117
# 31                         77.459954  22.540046
# 32                         84.435007  15.564993
# 33                         95.460718   4.539282
# 34                         80.820588  19.179412
# 35                         82.517344  17.482656
# 36                         99.513213   0.486787
# 37                         87.437104  12.562896
# 38                         93.696970   6.303030
# 39                         96.380606   3.619394
# 4                          90.950276   9.049724
# 40                         93.322541   6.677459
# 41                         87.755804  12.244196
# 42                         87.362244  12.637756
# 43                         89.046134  10.953866
# 44                         96.895728   3.104272
# 45                         76.473228  23.526772
# 46                         86.805556  13.194444
# 47                         81.045752  18.954248
# 48                         89.819724  10.180276
# 49                         76.146789  23.853211
# 5                          93.187348   6.812652
# 50                         82.732673  17.267327
# 51                         82.692308  17.307692
# 6                          95.477387   4.522613
# 7                          89.686099  10.313901
# 8                          83.312578  16.687422
# 9                          87.854251  12.145749
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: detailed_occupation_recode
# Unique categories: 47
#
# Top 10 categories:
# detailed_occupation_recode
# 0     0.493116
# 2     0.044820
# 26    0.039986
# 19    0.027958
# 29    0.026570
# 36    0.021319
# 34    0.020670
# 10    0.018759
# 16    0.017730
# 33    0.017204
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                       - 50000.    50000+.
# detailed_occupation_recode
# 0                           99.063503   0.936497
# 1                           75.243902  24.756098
# 10                          89.559038  10.440962
# 11                          33.832976  66.167024
# 12                          86.565978  13.434022
# 13                          95.068929   4.931071
# 14                          88.222222  11.777778
# 15                          78.867624  21.132376
# 16                          82.899557  17.100443
# 17                          73.747195  26.252805
# 18                          71.316425  28.683575
# 19                          97.469128   2.530872
# 2                           67.808115  32.191885
# 20                          95.098039   4.901961
# 21                          85.111663  14.888337
# 22                          93.819334   6.180666
# 23                          98.289238   1.710762
# 24                          97.920467   2.079533
# 25                          93.068470   6.931530
# 26                          97.478201   2.521799
# 27                          99.750831   0.249169
# 28                          84.477124  15.522876
# 29                          99.369613   0.630387
# 3                           79.736137  20.263863
# 30                          98.661029   1.338971
# 31                          98.822086   1.177914
# 32                          98.410042   1.589958
# 33                          89.250944  10.749056
# 34                          92.459071   7.540929
# 35                          90.356919   9.643081
# 36                          96.488696   3.511304
# 37                          96.210526   3.789474
# 38                          94.059623   5.940377
# 39                          90.120160   9.879840
# 4                           50.953545  49.046455
# 40                          97.169811   2.830189
# 41                          98.497496   1.502504
# 42                          98.453970   1.546030
# 43                          91.768741   8.231259
# 44                          98.607007   1.392993
# 45                          89.641434  10.358566
# 46                          82.692308  17.307692
# 5                           61.591963  38.408037
# 6                           65.366615  34.633385
# 7                           31.050228  68.949772
# 8                           82.707479  17.292521
# 9                           72.497746  27.502254
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: education
# Unique categories: 17
#
# Top 10 categories:
# education
# High school graduate                      0.247797
# Children                                  0.220311
# Some college but no degree                0.142714
# Bachelors degree(BA AB BS)                0.101658
# 7th and 8th grade                         0.041299
# 10th grade                                0.038704
# 11th grade                                0.035467
# Masters degree(MA MS MEng MEd MSW MBA)    0.033656
# 9th grade                                 0.031683
# Associates degree-occup /vocational       0.027503
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                                    - 50000.    50000+.
# education
# 10th grade                               99.152168   0.847832
# 11th grade                               98.882035   1.117965
# 12th grade no diploma                    98.528059   1.471941
# 1st 2nd 3rd or 4th grade                 99.258985   0.741015
# 5th or 6th grade                         99.198236   0.801764
# 7th and 8th grade                        99.130939   0.869061
# 9th grade                                99.352681   0.647319
# Associates degree-academic program       90.825830   9.174170
# Associates degree-occup /vocational      92.344022   7.655978
# Bachelors degree(BA AB BS)               80.238736  19.761264
# Children                                100.000000   0.000000
# Doctorate degree(PhD EdD)                48.274031  51.725969
# High school graduate                     96.036859   3.963141
# Less than 1st grade                      99.837266   0.162734
# Masters degree(MA MS MEng MEd MSW MBA)   68.779200  31.220800
# Prof school degree (MD DDS DVM LLB JD)   45.784938  54.215062
# Some college but no degree               93.703145   6.296855
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: enroll_in_edu_inst_last_wk
# Unique categories: 3
#
# Top 10 categories:
# enroll_in_edu_inst_last_wk
# Not in universe          0.935676
# High school              0.035262
# College or university    0.029062
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                       - 50000.   50000+.
# enroll_in_edu_inst_last_wk
# College or university       99.588332  0.411668
# High school                 99.951532  0.048468
# Not in universe             93.231336  6.768664
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: marital_stat
# Unique categories: 7
#
# Top 10 categories:
# marital_stat
# Married-civilian spouse present    0.431591
# Never married                      0.420328
# Divorced                           0.065483
# Widowed                            0.053919
# Separated                          0.017621
# Married-spouse absent              0.007626
# Married-A F spouse present         0.003432
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                            - 50000.    50000+.
# marital_stat
# Divorced                         91.835882   8.164118
# Married-A F spouse present       97.908367   2.091633
# Married-civilian spouse present  88.562671  11.437329
# Married-spouse absent            94.038548   5.961452
# Never married                    98.648418   1.351582
# Separated                        95.557711   4.442289
# Widowed                          96.716115   3.283885
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: major_industry_code
# Unique categories: 24
#
# Top 10 categories:
# major_industry_code
# Not in universe or children          0.493116
# Retail trade                         0.088105
# Manufacturing-durable goods          0.046006
# Education                            0.042752
# Manufacturing-nondurable goods       0.035163
# Finance insurance and real estate    0.031325
# Construction                         0.030935
# Business and repair services         0.029520
# Medical except hospital              0.023883
# Public administration                0.023203
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                                - 50000.    50000+.
# major_industry_code
# Agriculture                          94.125530   5.874470
# Armed Forces                         82.692308  17.307692
# Business and repair services         89.231126  10.768874
# Communications                       76.632883  23.367117
# Construction                         90.950276   9.049724
# Education                            89.046134  10.953866
# Entertainment                        93.322541   6.677459
# Finance insurance and real estate    81.754692  18.245308
# Forestry and fisheries               86.805556  13.194444
# Hospital services                    87.755804  12.244196
# Manufacturing-durable goods          83.512891  16.487109
# Manufacturing-nondurable goods       87.489064  12.510936
# Medical except hospital              87.362244  12.637756
# Mining                               74.324324  25.675676
# Not in universe or children          99.063503   0.936497
# Other professional services          76.473228  23.526772
# Personal services except private HH  96.380606   3.619394
# Private household services           99.513213   0.486787
# Public administration                82.262817  17.737183
# Retail trade                         95.460718   4.539282
# Social services                      96.895728   3.104272
# Transportation                       88.471725  11.528275
# Utilities and sanitary services      77.459954  22.540046
# Wholesale trade                      84.435007  15.564993
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: major_occupation_code
# Unique categories: 15
#
# Top 10 categories:
# major_occupation_code
# Not in universe                          0.493116
# Adm support including clerical           0.075495
# Professional specialty                   0.071123
# Executive admin and managerial           0.064204
# Other service                            0.062454
# Sales                                    0.060837
# Precision production craft & repair      0.054251
# Machine operators assmblrs & inspctrs    0.032685
# Handlers equip cleaners etc              0.021179
# Transportation and material moving       0.020714
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                                  - 50000.    50000+.
# major_occupation_code
# Adm support including clerical         96.925654   3.074346
# Armed Forces                           82.692308  17.307692
# Executive admin and managerial         71.213331  28.786669
# Farming forestry and fishing           95.129800   4.870200
# Handlers equip cleaners etc            98.273079   1.726921
# Machine operators assmblrs & inspctrs  96.391968   3.608032
# Not in universe                        99.063503   0.936497
# Other service                          98.949154   1.050846
# Precision production craft & repair    90.807133   9.192867
# Private household services             99.750831   0.249169
# Professional specialty                 75.022829  24.977171
# Protective services                    84.477124  15.522876
# Sales                                  87.212046  12.787954
# Technicians and related support        88.485523  11.514477
# Transportation and material moving     93.085809   6.914191
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: race
# Unique categories: 5
#
# Top 10 categories:
# race
# White                          0.836753
# Black                          0.102830
# Asian or Pacific Islander      0.029769
# Other                          0.018906
# Amer Indian Aleut or Eskimo    0.011742
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                        - 50000.   50000+.
# race
# Amer Indian Aleut or Eskimo  97.758370  2.241630
# Asian or Pacific Islander    92.800551  7.199449
# Black                        97.284180  2.715820
# Other                        97.721931  2.278069
# White                        93.087601  6.912399
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: hispanic_origin
# Unique categories: 10
#
# Top 10 categories:
# hispanic_origin
# All other                    0.859296
# Mexican-American             0.040721
# Mexican (Mexicano)           0.037149
# Central or South American    0.020075
# Puerto Rican                 0.016671
# Other Spanish                0.012688
# Cuban                        0.005927
# NA                           0.004338
# Chicano                      0.001613
# Do not know                  0.001521
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                      - 50000.   50000+.
# hispanic_origin
# All other                  92.989295  7.010705
# Central or South American  97.837562  2.162438
# Chicano                    97.033898  2.966102
# Cuban                      93.886967  6.113033
# Do not know                96.853933  3.146067
# Mexican (Mexicano)         98.721016  1.278984
# Mexican-American           97.918241  2.081759
# NA                         94.247439  5.752561
# Other Spanish              96.821121  3.178879
# Puerto Rican               97.847037  2.152963
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: sex
# Unique categories: 2
#
# Top 10 categories:
# sex
# Female    0.52134
# Male      0.47866
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income   - 50000.    50000+.
# sex
# Female  97.398340   2.601660
# Male    89.573812  10.426188
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: member_of_a_labor_union
# Unique categories: 3
#
# Top 10 categories:
# member_of_a_labor_union
# Not in universe    0.902447
# No                 0.082256
# Yes                0.015297
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                    - 50000.    50000+.
# member_of_a_labor_union
# No                       88.730053  11.269947
# Not in universe          94.226377   5.773623
# Yes                      86.301676  13.698324
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: reason_for_unemployment
# Unique categories: 6
#
# Top 10 categories:
# reason_for_unemployment
# Not in universe          0.968563
# Other job loser          0.010754
# Re-entrant               0.010395
# Job loser - on layoff    0.005073
# Job leaver               0.003022
# New entrant              0.002194
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                    - 50000.   50000+.
# reason_for_unemployment
# Job leaver               96.493213  3.506787
# Job loser - on layoff    97.574124  2.425876
# New entrant              99.688474  0.311526
# Not in universe          93.537743  6.462257
# Other job loser          94.914177  5.085823
# Re-entrant               99.079250  0.920750
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: full_or_part_time_employment_stat
# Unique categories: 8
#
# Top 10 categories:
# full_or_part_time_employment_stat
# Children or Armed Forces              0.611513
# Full-time schedules                   0.209154
# Not in labor force                    0.136951
# PT for non-econ reasons usually FT    0.017286
# Unemployed full-time                  0.012015
# PT for econ reasons usually PT        0.006125
# Unemployed part- time                 0.004280
# PT for econ reasons usually FT        0.002676
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                               - 50000.    50000+.
# full_or_part_time_employment_stat
# Children or Armed Forces            95.107827   4.892173
# Full-time schedules                 86.791528  13.208472
# Not in labor force                  98.227880   1.772120
# PT for econ reasons usually FT      94.636015   5.363985
# PT for econ reasons usually PT      86.941964  13.058036
# PT for non-econ reasons usually FT  88.293455  11.706545
# Unemployed full-time                96.415363   3.584637
# Unemployed part- time               97.603834   2.396166
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: tax_filer_stat
# Unique categories: 6
#
# Top 10 categories:
# tax_filer_stat
# Nonfiler                        0.361658
# Joint both under 65             0.344980
# Single                          0.192401
# Joint both 65+                  0.042776
# Head of household               0.038223
# Joint one under 65 & one 65+    0.019962
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                         - 50000.    50000+.
# tax_filer_stat
# Head of household             94.079771   5.920229
# Joint both 65+                94.757871   5.242129
# Joint both under 65           86.807895  13.192105
# Joint one under 65 & one 65+  91.883562   8.116438
# Nonfiler                      99.952742   0.047258
# Single                        93.938210   6.061790
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: region_of_previous_residence
# Unique categories: 6
#
# Top 10 categories:
# region_of_previous_residence
# Not in universe    0.920130
# South              0.024891
# West               0.020841
# Midwest            0.017911
# Northeast          0.013724
# Abroad             0.002502
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                         - 50000.   50000+.
# region_of_previous_residence
# Abroad                        96.448087  3.551913
# Midwest                       96.755725  3.244275
# Northeast                     94.221669  5.778331
# Not in universe               93.453920  6.546080
# South                         96.347157  3.652843
# West                          95.850418  4.149582
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: state_of_previous_residence
# Unique categories: 51
#
# Top 10 categories:
# state_of_previous_residence
# Not in universe    0.920130
# California         0.008843
# Utah               0.005442
# Florida            0.004423
# North Carolina     0.004122
# ?                  0.003534
# Abroad             0.003196
# Oklahoma           0.003138
# Minnesota          0.002936
# Indiana            0.002813
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                        - 50000.   50000+.
# state_of_previous_residence
# ?                            93.810445  6.189555
# Abroad                       96.577540  3.422460
# Alabama                      97.213622  2.786378
# Alaska                       91.484185  8.515815
# Arizona                      96.842105  3.157895
# Arkansas                     97.350993  2.649007
# California                   95.709316  4.290684
# Colorado                     94.886364  5.113636
# Connecticut                  90.109890  9.890110
# Delaware                     95.867769  4.132231
# District of Columbia         91.616766  8.383234
# Florida                      95.440495  4.559505
# Georgia                      97.928994  2.071006
# Idaho                        95.454545  4.545455
# Illinois                     96.603774  3.396226
# Indiana                      96.476306  3.523694
# Iowa                         96.850394  3.149606
# Kansas                       98.173516  1.826484
# Kentucky                     96.338028  3.661972
# Louisiana                    97.427653  2.572347
# Maine                        95.652174  4.347826
# Maryland                     97.663551  2.336449
# Massachusetts                93.750000  6.250000
# Michigan                     94.522692  5.477308
# Minnesota                    96.391153  3.608847
# Mississippi                  96.453901  3.546099
# Missouri                     97.540984  2.459016
# Montana                      96.374622  3.625378
# Nebraska                     98.194946  1.805054
# Nevada                       97.628458  2.371542
# New Hampshire                96.910112  3.089888
# New Jersey                   91.150442  8.849558
# New Mexico                   93.613933  6.386067
# New York                     97.019868  2.980132
# North Carolina               94.029851  5.970149
# North Dakota                 96.388889  3.611111
# Not in universe              93.453920  6.546080
# Ohio                         97.419355  2.580645
# Oklahoma                     96.623094  3.376906
# Oregon                       97.383721  2.616279
# Pennsylvania                 96.621622  3.378378
# South Carolina               96.527778  3.472222
# South Dakota                 97.169811  2.830189
# Tennessee                    97.627119  2.372881
# Texas                        96.369637  3.630363
# Utah                         97.298995  2.701005
# Vermont                      97.586207  2.413793
# Virginia                     97.826087  2.173913
# West Virginia                94.610778  5.389222
# Wisconsin                    96.407186  3.592814
# Wyoming                      96.774194  3.225806
#
# ⚠️ Found suspicious categories: ['?']
# ================================================================================
#
#
# ================================================================================
# COLUMN: detailed_household_and_family_stat
# Unique categories: 38
#
# Top 10 categories:
# detailed_household_and_family_stat
# Householder                                        0.273211
# Child <18 never marr not in subfamily              0.235297
# Spouse of householder                              0.212958
# Nonfamily householder                              0.114295
# Child 18+ never marr Not in a subfamily            0.062003
# Secondary individual                               0.031598
# Other Rel 18+ ever marr not in subfamily           0.010156
# Grandchild <18 never marr child of subfamily RP    0.009222
# Other Rel 18+ never marr not in subfamily          0.008751
# Grandchild <18 never marr not in subfamily         0.005302
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                                             - 50000.    50000+.
# detailed_household_and_family_stat
# Child 18+ ever marr Not in a subfamily            97.496617   2.503383
# Child 18+ ever marr RP of subfamily               98.048780   1.951220
# Child 18+ never marr Not in a subfamily           99.338442   0.661558
# Child 18+ never marr RP of subfamily              99.665924   0.334076
# Child 18+ spouse of subfamily RP                  98.029557   1.970443
# Child <18 ever marr RP of subfamily              100.000000   0.000000
# Child <18 ever marr not in subfamily             100.000000   0.000000
# Child <18 never marr RP of subfamily             100.000000   0.000000
# Child <18 never marr not in subfamily             99.997095   0.002905
# Child <18 spouse of subfamily RP                 100.000000   0.000000
# Child under 18 of RP of unrel subfamily          100.000000   0.000000
# Grandchild 18+ ever marr RP of subfamily         100.000000   0.000000
# Grandchild 18+ ever marr not in subfamily         98.148148   1.851852
# Grandchild 18+ never marr RP of subfamily        100.000000   0.000000
# Grandchild 18+ never marr not in subfamily        99.484536   0.515464
# Grandchild 18+ spouse of subfamily RP            100.000000   0.000000
# Grandchild <18 ever marr not in subfamily        100.000000   0.000000
# Grandchild <18 never marr RP of subfamily        100.000000   0.000000
# Grandchild <18 never marr child of subfamily RP  100.000000   0.000000
# Grandchild <18 never marr not in subfamily       100.000000   0.000000
# Householder                                       85.237964  14.762036
# In group quarters                                 98.909091   1.090909
# Nonfamily householder                             92.032778   7.967222
# Other Rel 18+ ever marr RP of subfamily           97.101449   2.898551
# Other Rel 18+ ever marr not in subfamily          98.956580   1.043420
# Other Rel 18+ never marr RP of subfamily         100.000000   0.000000
# Other Rel 18+ never marr not in subfamily         98.671875   1.328125
# Other Rel 18+ spouse of subfamily RP              96.370968   3.629032
# Other Rel <18 ever marr RP of subfamily          100.000000   0.000000
# Other Rel <18 ever marr not in subfamily         100.000000   0.000000
# Other Rel <18 never marr child of subfamily RP   100.000000   0.000000
# Other Rel <18 never marr not in subfamily        100.000000   0.000000
# Other Rel <18 never married RP of subfamily      100.000000   0.000000
# Other Rel <18 spouse of subfamily RP             100.000000   0.000000
# RP of unrelated subfamily                         98.828125   1.171875
# Secondary individual                              96.365210   3.634790
# Spouse of RP of unrelated subfamily               90.789474   9.210526
# Spouse of householder                             94.497681   5.502319
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: detailed_household_summary_in_household
# Unique categories: 8
#
# Top 10 categories:
# detailed_household_summary_in_household
# Householder                             0.387585
# Child under 18 never married            0.235799
# Spouse of householder                   0.213013
# Child 18 or older                       0.074326
# Other relative of householder           0.049318
# Nonrelative of householder              0.039091
# Group Quarters- Secondary individual    0.000632
# Child under 18 ever married             0.000236
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                                     - 50000.    50000+.
# detailed_household_summary_in_household
# Child 18 or older                         99.153790   0.846210
# Child under 18 ever married              100.000000   0.000000
# Child under 18 never married              99.997101   0.002899
# Group Quarters- Secondary individual      98.918919   1.081081
# Householder                               87.243800  12.756200
# Nonrelative of householder                96.895768   3.104232
# Other relative of householder             99.078181   0.921819
# Spouse of householder                     94.499093   5.500907
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: migration_code-change_in_msa
# Unique categories: 10
#
# Top 10 categories:
# migration_code-change_in_msa
# ?                   0.499542
# Nonmover            0.413663
# MSA to MSA          0.054059
# NonMSA to nonMSA    0.014138
# Not in universe     0.006925
# MSA to nonMSA       0.003931
# NonMSA to MSA       0.003104
# Not identifiable    0.002153
# Abroad to MSA       0.002112
# Abroad to nonMSA    0.000373
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                          - 50000.   50000+.
# migration_code-change_in_msa
# ?                              93.246248  6.753752
# Abroad to MSA                  96.116505  3.883495
# Abroad to nonMSA               98.165138  1.834862
# MSA to MSA                     95.270313  4.729687
# MSA to nonMSA                  96.782609  3.217391
# NonMSA to MSA                  95.925110  4.074890
# NonMSA to nonMSA               98.162476  1.837524
# Nonmover                       93.595115  6.404885
# Not identifiable               96.349206  3.650794
# Not in universe               100.000000  0.000000
#
# ⚠️ Found suspicious categories: ['?']
# ================================================================================
#
#
# ================================================================================
# COLUMN: migration_code-change_in_reg
# Unique categories: 9
#
# Top 10 categories:
# migration_code-change_in_reg
# ?                                 0.499542
# Nonmover                          0.413663
# Same county                       0.049947
# Different county same state       0.014059
# Not in universe                   0.006925
# Different region                  0.006016
# Different state same division     0.004994
# Abroad                            0.002502
# Different division same region    0.002352
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                            - 50000.   50000+.
# migration_code-change_in_reg
# ?                                93.246248  6.753752
# Abroad                           96.448087  3.551913
# Different county same state      95.088743  4.911257
# Different division same region   94.040698  5.959302
# Different region                 94.090909  5.909091
# Different state same division    95.345654  4.654346
# Nonmover                         93.595115  6.404885
# Not in universe                 100.000000  0.000000
# Same county                      96.537093  3.462907
#
# ⚠️ Found suspicious categories: ['?']
# ================================================================================
#
#
# ================================================================================
# COLUMN: migration_code-move_within_reg
# Unique categories: 10
#
# Top 10 categories:
# migration_code-move_within_reg
# ?                               0.499542
# Nonmover                        0.413663
# Same county                     0.049947
# Different county same state     0.014059
# Not in universe                 0.006925
# Different state in South        0.004943
# Different state in West         0.003538
# Different state in Midwest      0.002707
# Abroad                          0.002502
# Different state in Northeast    0.002174
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                            - 50000.   50000+.
# migration_code-move_within_reg
# ?                                93.246248  6.753752
# Abroad                           96.448087  3.551913
# Different county same state      95.088743  4.911257
# Different state in Midwest       95.328283  4.671717
# Different state in Northeast     91.981132  8.018868
# Different state in South         94.813278  5.186722
# Different state in West          95.169082  4.830918
# Nonmover                         93.595115  6.404885
# Not in universe                 100.000000  0.000000
# Same county                      96.537093  3.462907
#
# ⚠️ Found suspicious categories: ['?']
# ================================================================================
#
#
# ================================================================================
# COLUMN: live_in_this_house_1_year_ago
# Unique categories: 3
#
# Top 10 categories:
# live_in_this_house_1_year_ago
# Not in universe under 1 year old    0.506467
# Yes                                 0.413663
# No                                  0.079870
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                             - 50000.   50000+.
# live_in_this_house_1_year_ago
# No                                95.947103  4.052897
# Not in universe under 1 year old  93.338598  6.661402
# Yes                               93.595115  6.404885
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: migration_prev_res_in_sunbelt
# Unique categories: 4
#
# Top 10 categories:
# migration_prev_res_in_sunbelt
# ?                  0.499542
# Not in universe    0.420588
# No                 0.050361
# Yes                0.029509
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                          - 50000.   50000+.
# migration_prev_res_in_sunbelt
# ?                              93.246248  6.753752
# No                             95.574561  4.425439
# Not in universe                93.700576  6.299424
# Yes                            96.582880  3.417120
#
# ⚠️ Found suspicious categories: ['?']
# ================================================================================
#
#
# ================================================================================
# COLUMN: family_members_under_18
# Unique categories: 5
#
# Top 10 categories:
# family_members_under_18
# Not in universe           0.739966
# Both parents present      0.179084
# Mother only present       0.063070
# Father only present       0.009568
# Neither parent present    0.008313
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                     - 50000.   50000+.
# family_members_under_18
# Both parents present      99.996183  0.003817
# Father only present      100.000000  0.000000
# Mother only present      100.000000  0.000000
# Neither parent present   100.000000  0.000000
# Not in universe           91.423569  8.576431
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: country_of_birth_father
# Unique categories: 43
#
# Top 10 categories:
# country_of_birth_father
# United-States         0.793191
# Mexico                0.050955
# ?                     0.034592
# Puerto-Rico           0.013533
# Italy                 0.011379
# Canada                0.006970
# Germany               0.006850
# Dominican-Republic    0.006700
# Poland                0.006286
# Philippines           0.005951
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                         - 50000.    50000+.
# country_of_birth_father
# ?                             91.749012   8.250988
# Cambodia                      97.749196   2.250804
# Canada                        90.583619   9.416381
# China                         90.792634   9.207366
# Columbia                      96.681416   3.318584
# Cuba                          94.372802   5.627198
# Dominican-Republic            99.132653   0.867347
# Ecuador                       96.847636   3.152364
# El-Salvador                   99.055968   0.944032
# England                       89.931741  10.068259
# France                        90.217391   9.782609
# Germany                       91.866267   8.133733
# Greece                        87.795993  12.204007
# Guatemala                     99.702381   0.297619
# Haiti                         97.628458   2.371542
# Holand-Netherlands            88.888889  11.111111
# Honduras                      99.665552   0.334448
# Hong Kong                     94.838710   5.161290
# Hungary                       89.662447  10.337553
# India                         86.312217  13.687783
# Iran                          86.607143  13.392857
# Ireland                       87.239264  12.760736
# Italy                         93.181135   6.818865
# Jamaica                       96.197183   3.802817
# Japan                         89.966555  10.033445
# Laos                          98.717949   1.282051
# Mexico                        98.685181   1.314819
# Nicaragua                     97.959184   2.040816
# Outlying-U S (Guam USVI etc)  95.726496   4.273504
# Panama                        97.560976   2.439024
# Peru                          97.565923   2.434077
# Philippines                   93.107410   6.892590
# Poland                        91.245242   8.754758
# Portugal                      95.360825   4.639175
# Puerto-Rico                   97.575145   2.424855
# Scotland                      91.803279   8.196721
# South Korea                   94.515306   5.484694
# Taiwan                        90.780142   9.219858
# Thailand                      94.444444   5.555556
# Trinadad&Tobago               97.237569   2.762431
# United-States                 93.354392   6.645608
# Vietnam                       97.919762   2.080238
# Yugoslavia                    93.823529   6.176471
#
# ⚠️ Found suspicious categories: ['?']
# ================================================================================
#
#
# ================================================================================
# COLUMN: country_of_birth_mother
# Unique categories: 43
#
# Top 10 categories:
# country_of_birth_mother
# United-States    0.799897
# Mexico           0.049988
# ?                0.031342
# Puerto-Rico      0.012497
# Italy            0.009427
# Canada           0.007359
# Germany          0.007035
# Philippines      0.006392
# Cuba             0.005801
# Poland           0.005790
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                          - 50000.    50000+.
# country_of_birth_mother
# ?                              92.289235   7.710765
# Cambodia                       96.875000   3.125000
# Canada                         90.246168   9.753832
# China                          90.852575   9.147425
# Columbia                       97.114317   2.885683
# Cuba                           93.930466   6.069534
# Dominican-Republic             99.141104   0.858896
# Ecuador                        96.701389   3.298611
# El-Salvador                    98.352654   1.647346
# England                        89.307229  10.692771
# France                         88.039867  11.960133
# Germany                        91.302235   8.697765
# Greece                         90.865385   9.134615
# Guatemala                      99.551570   0.448430
# Haiti                          97.660819   2.339181
# Holand-Netherlands             85.507246  14.492754
# Honduras                       99.393939   0.606061
# Hong Kong                      94.155844   5.844156
# Hungary                        89.957265  10.042735
# India                          85.634119  14.365881
# Iran                           85.121107  14.878893
# Ireland                        88.046958  11.953042
# Italy                          94.452502   5.547498
# Jamaica                        96.005706   3.994294
# Japan                          89.876881  10.123119
# Laos                           98.672566   1.327434
# Mexico                         98.557166   1.442834
# Nicaragua                      98.144330   1.855670
# Outlying-U S (Guam USVI etc)   99.082569   0.917431
# Panama                        100.000000   0.000000
# Peru                           97.696737   2.303263
# Philippines                    93.850267   6.149733
# Poland                         91.440378   8.559622
# Portugal                       95.568401   4.431599
# Puerto-Rico                    97.784464   2.215536
# Scotland                       89.325843  10.674157
# South Korea                    94.894562   5.105438
# Taiwan                         92.000000   8.000000
# Thailand                       95.876289   4.123711
# Trinadad&Tobago                96.794872   3.205128
# United-States                  93.340456   6.659544
# Vietnam                        98.016997   1.983003
# Yugoslavia                     95.340502   4.659498
#
# ⚠️ Found suspicious categories: ['?']
# ================================================================================
#
#
# ================================================================================
# COLUMN: country_of_birth_self
# Unique categories: 43
#
# Top 10 categories:
# country_of_birth_self
# United-States         0.884146
# Mexico                0.029691
# ?                     0.017604
# Puerto-Rico           0.007147
# Philippines           0.004437
# Germany               0.004341
# Cuba                  0.004321
# Canada                0.003575
# El-Salvador           0.003524
# Dominican-Republic    0.003459
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                         - 50000.    50000+.
# country_of_birth_self
# ?                             91.048544   8.951456
# Cambodia                      98.726115   1.273885
# Canada                        90.152964   9.847036
# China                         92.587413   7.412587
# Columbia                      96.589147   3.410853
# Cuba                          92.484177   7.515823
# Dominican-Republic            98.814229   1.185771
# Ecuador                       96.173469   3.826531
# El-Salvador                   98.254122   1.745878
# England                       87.941176  12.058824
# France                        86.111111  13.888889
# Germany                       91.811024   8.188976
# Greece                        87.782805  12.217195
# Guatemala                     99.212598   0.787402
# Haiti                         96.941896   3.058104
# Holand-Netherlands            85.294118  14.705882
# Honduras                      99.095023   0.904977
# Hong Kong                     90.789474   9.210526
# Hungary                       88.990826  11.009174
# India                         82.182986  17.817014
# Iran                          81.165919  18.834081
# Ireland                       88.834951  11.165049
# Italy                         93.178295   6.821705
# Jamaica                       95.362903   4.637097
# Japan                         88.588008  11.411992
# Laos                          98.742138   1.257862
# Mexico                        98.560903   1.439097
# Nicaragua                     98.850575   1.149425
# Outlying-U S (Guam USVI etc)  97.575758   2.424242
# Panama                        97.435897   2.564103
# Peru                          96.915167   3.084833
# Philippines                   91.217257   8.782743
# Poland                        93.297101   6.702899
# Portugal                      95.149254   4.850746
# Puerto-Rico                   97.656624   2.343376
# Scotland                      86.363636  13.636364
# South Korea                   94.184397   5.815603
# Taiwan                        85.815603  14.184397
# Thailand                      94.350282   5.649718
# Trinadad&Tobago               96.491228   3.508772
# United-States                 93.540094   6.459906
# Vietnam                       97.552448   2.447552
# Yugoslavia                    94.736842   5.263158
#
# ⚠️ Found suspicious categories: ['?']
# ================================================================================
#
#
# ================================================================================
# COLUMN: citizenship
# Unique categories: 5
#
# Top 10 categories:
# citizenship
# Native- Born in the United States              0.884163
# Foreign born- Not a citizen of U S             0.068597
# Foreign born- U S citizen by naturalization    0.030285
# Native- Born abroad of American Parent(s)      0.009243
# Native- Born in Puerto Rico or U S Outlying    0.007712
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                                        - 50000.    50000+.
# citizenship
# Foreign born- Not a citizen of U S           96.407215   3.592785
# Foreign born- U S citizen by naturalization  89.853273  10.146727
# Native- Born abroad of American Parent(s)    93.121302   6.878698
# Native- Born in Puerto Rico or U S Outlying  97.650709   2.349291
# Native- Born in the United States            93.540219   6.459781
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: own_business_or_self_employed
# Unique categories: 3
#
# Top 10 categories:
# own_business_or_self_employed
# 0    0.902844
# 2    0.083353
# 1    0.013803
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                          - 50000.    50000+.
# own_business_or_self_employed
# 0                              94.072927   5.927073
# 1                              77.885092  22.114908
# 2                              91.716219   8.283781
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: fill_inc_questionnaire_for_veteran's_admin
# Unique categories: 3
#
# Top 10 categories:
# fill_inc_questionnaire_for_veteran's_admin
# Not in universe    0.989708
# No                 0.008276
# Yes                0.002017
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income                                       - 50000.    50000+.
# fill_inc_questionnaire_for_veteran's_admin
# No                                          86.327964  13.672036
# Not in universe                             93.709656   6.290344
# Yes                                         95.932203   4.067797
#
# No suspicious categories found.
# ================================================================================
#
#
# ================================================================================
# COLUMN: veterans_benefits
# Unique categories: 3
#
# Top 10 categories:
# veterans_benefits
# 2    0.769455
# 0    0.220253
# 1    0.010292
# Name: proportion, dtype: float64
#
# Target distribution (% earning >50K) per category:
# income               - 50000.    50000+.
# veterans_benefits
# 0                  100.000000   0.000000
# 1                   88.209897  11.790103
# 2                   91.909073   8.090927
#
# No suspicious categories found.
# ================================================================================

# %%
# this file is then saved as a pickle file, later loaded in the nex ipynb, as a .csv format do not hold 
# account of the changes regarindg the data type of the column for instance.

# df_full.to_pickle("csv_preparation/df_post_eda.pkl")
